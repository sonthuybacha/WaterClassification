# %%
#hide
from WaterClassification.core import *

# %% [markdown]
# # Water classification project
#
# > The objective of this project is to provide a water color classification based on remote sensed images

# %% [markdown]
# This file will become your README and also the index of your documentation.

# %% [markdown]
# ## Install

# %% [markdown]
# `pip install your_project_name`

# %% [markdown]
# ### Subitem for installation

# %% [markdown]
# ## How to use

# %% [markdown]
# Fill me in please! Don't forget code examples:

# %%
1+1
# Out:
# 2

# %% [markdown]
# ## New content

# %% [markdown]
# Outro conteúdo com nível 2

# %%
2+2
# Out:
# 4

# %% [markdown]
# # Outro cabeçalho nivel 1
# > Teste
